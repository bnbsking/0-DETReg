# %%
import sys
packagePath = "/home/jovyan/data-vol-1/detreg_latest/_packages"
sys.path += [] if packagePath in sys.path else [packagePath]
import result

# %%
gtPath  = "/home/jovyan/data-vol-1/detreg_latest/_data/downstream/c7_0620/voc_val"
pdPath  = "/home/jovyan/data-vol-1/detreg_latest/_exps/downstream/coco_40k_ep200_c70620/viz_txt"
imgPath = "/home/jovyan/data-vol-1/detreg_latest/_exps/downstream/coco_40k_ep200_c70620/viz_jpg"
classesTxtPath = "/home/jovyan/data-vol-1/detreg_latest/_data/downstream/c7_0620/yolo_val/classes.txt"
classL = ['PLC','NPLC','PAC','NPAC','Tetra','HDPE','PET']
classNumL = [146, 54, 2115, 3306, 248, 11, 23]
obj = result.Result(gtPath, pdPath, imgPath, classesTxtPath, classL, classNumL)
obj.plotAP()
obj.plotAP(showMAP=True, showAPS=True)
obj.plotPR()
#obj.plotConfusion()
obj.plotConfusion(strategy="precision")
obj.getBlockImgs(2,0)
# Out:
# load pr.npy from cache
# apL=[0.74, 0.0, 0.76, 0.73, 0.81, 0.88, 0.75], mAP=0.67, wmAP=0.74
# bestScore=0.91, best_threshold=0.96
# len(glob.glob(folder+'/*.jpg'))=8

# %%
gtPath  = "/home/jovyan/data-vol-1/detreg_latest/_data/downstream/labv3/voc_test/"
pdPath  = "/home/jovyan/data-vol-1/detreg_latest/_exps/downstream/xavier_20k_ep219/viz_txt/"
imgPath = "/home/jovyan/data-vol-1/detreg_latest/_exps/downstream/xavier_20k_ep219/viz_jpg"
classesTxtPath = "/home/jovyan/data-vol-1/detreg_latest/_data/downstream/labv3/classes.txt"
classL = ['PLC','NPLC','PAC','NPAC','Tetra']
classNumL = [2501, 25, 2880, 771, 170]
obj = result.Result(gtPath, pdPath, imgPath, classesTxtPath, classL, classNumL)
obj.plotAP()
obj.plotAP(showMAP=False, showAPS=True)
obj.plotPR()
obj.plotConfusion()
obj.plotConfusion(strategy="precision")
# Out:
# load pr.npy from cache
# apL=[0.981, 0.551, 0.977, 0.958, 0.919], mAP=0.877, wmAP=0.973
# bestScore=0.98, best_threshold=0.78
# bestScore=0.99, best_threshold=0.99

# %%
gtPath  = "/home/jovyan/data-vol-1/detreg_latest/_data/downstream/labv3/voc_test/"
pdPath  = "/home/jovyan/data-vol-1/detreg_latest/_exps/downstream/xavier_30k_ep219/viz_txt/"
imgPath = "/home/jovyan/data-vol-1/detreg_latest/_exps/downstream/xavier_30k_ep219/viz_jpg"
classesTxtPath = "/home/jovyan/data-vol-1/detreg_latest/_data/downstream/labv3/classes.txt"
classL = ['PLC','NPLC','PAC','NPAC','Tetra']
classNumL = [2501, 25, 2880, 771, 170]
obj = result.Result(gtPath, pdPath, imgPath, classesTxtPath, classL, classNumL)
obj.plotAP()
obj.plotAP(showMAP=False, showAPS=True)
obj.plotPR()
obj.plotConfusion()
obj.plotConfusion(strategy="precision")
#obj.getBlockImgs(2,0)
# Out:
# load pr.npy from cache
# apL=[0.98, 0.954, 0.981, 0.965, 0.97], mAP=0.97, wmAP=0.978
# bestScore=0.98, best_threshold=0.82
# bestScore=0.99, best_threshold=0.98

# %%
gtPath  = "/home/jovyan/data-vol-1/detreg_latest/_data/downstream/labv3/voc_test/"
pdPath  = "/home/jovyan/data-vol-1/detreg_latest/_exps/downstream/40k_ep200_labv3/viz_txt/"
imgPath = "/home/jovyan/data-vol-1/detreg_latest/_exps/downstream/40k_ep200_labv3/viz_jpg"
classesTxtPath = "/home/jovyan/data-vol-1/detreg_latest/_data/downstream/labv3/classes.txt"
classL = ['PLC','NPLC','PAC','NPAC','Tetra']
classNumL = [2501, 25, 2880, 771, 170]
obj = result.Result(gtPath, pdPath, imgPath, classesTxtPath, classL, classNumL)
obj.plotAP()
obj.plotAP(showMAP=False, showAPS=True)
obj.plotPR()
obj.plotConfusion()
obj.plotConfusion(strategy="precision")
#obj.getBlockImgs(2,0)
# Out:
# load pr.npy from cache
# apL=[0.986, 0.935, 0.989, 0.976, 0.953], mAP=0.968, wmAP=0.985
# bestScore=0.99, best_threshold=0.73
# bestScore=1.0, best_threshold=0.98

# %%
# index may start from 0
gtPath  = "/home/jovyan/data-vol-1/detreg_latest/_data/downstream/labv3/voc_test/"
pdPath  = "/home/jovyan/data-vol-1/detreg_latest/_exps/downstream/xavier_60k_ep154/viz_txt/"
imgPath = "/home/jovyan/data-vol-1/detreg_latest/_exps/downstream/xavier_60k_ep154/viz_jpg"
classesTxtPath = "/home/jovyan/data-vol-1/detreg_latest/_data/downstream/labv3/classes.txt"
classL = ['PLC','NPLC','PAC','NPAC','Tetra']
classNumL = [2501, 25, 2880, 771, 170]
obj = result.Result(gtPath, pdPath, imgPath, classesTxtPath, classL, classNumL)
obj.plotAP()
obj.plotAP(showMAP=False, showAPS=True)
obj.plotPR()
obj.plotConfusion()
obj.plotConfusion(strategy="precision")
#obj.getBlockImgs(2,0)
# Out:
# load pr.npy from cache
# apL=[0.976, 0.96, 0.97, 0.961, 0.933], mAP=0.96, wmAP=0.97
# bestScore=0.98, best_threshold=0.7
# bestScore=0.99, best_threshold=0.97

# %%
# index may start from 0
gtPath  = "/home/jovyan/data-vol-1/detreg_latest/_data/downstream/labv3/voc_test/"
pdPath  = "/home/jovyan/data-vol-1/detreg_latest/_exps/downstream/xavier_bb40k_ep149/viz_txt/"
imgPath = "/home/jovyan/data-vol-1/detreg_latest/_exps/downstream/xavier_bb40k_ep149/viz_jpg"
classesTxtPath = "/home/jovyan/data-vol-1/detreg_latest/_data/downstream/labv3/classes.txt"
classL = ['PLC','NPLC','PAC','NPAC','Tetra']
classNumL = [2501, 25, 2880, 771, 170]
obj = result.Result(gtPath, pdPath, imgPath, classesTxtPath, classL, classNumL)
obj.plotAP()
obj.plotAP(showMAP=False, showAPS=True)
obj.plotPR()
obj.plotConfusion()
obj.plotConfusion(strategy="precision")
# Out:
# threshold=1.00
# apL=[0.974, 0.754, 0.981, 0.962, 0.975], mAP=0.929, wmAP=0.975
# bestScore=0.98, best_threshold=0.83
# bestScore=0.99, best_threshold=0.98
